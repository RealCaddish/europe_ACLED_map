# %% [markdown]
# # East Europe Conflicts Data

# %% [markdown]
# Taking the ACLED dataset for Ukraine, Russia, and Belarus from 12/04/2018 - 12/09/2021. This notebook seeks to remove unneccessary columns and sort the dataset by year.

# %%
import geopandas as gpd 
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option("max_columns", 31)

# %%
data = gpd.read_file('2018-12-04-2021-12-09-Belarus-Lithuania-Poland-Russia-Ukraine.csv')

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 48635 entries, 0 to 48634
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           48635 non-null  object
#  1   iso               48635 non-null  object
#  2   event_id_cnty     48635 non-null  object
#  3   event_id_no_cnty  48635 non-null  object
#  4   event_date        48635 non-null  object
#  5   year              48635 non-null  object
#  6   time_precision    48635 non-null  object
#  7   event_type        48635 non-null  object
#  8   sub_event_type    48635 non-null  object
#  9   actor1            48635 non-null  object
#  10  assoc_actor_1     48635 non-null  object
#  11  inter1            48635 non-null  object
#  12  actor2            48635 non-null  object
#  13  assoc_actor_2     48635 non-null  object
#  14  inter2            48635 non-null  object
#  15  interaction       48635 non-null  object
# ...

# %%
data.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty        event_date  year  \
# 0  8678620  804      UKR49956            49956  03 December 2021  2021
# 1  8678625  804      UKR50017            50017  03 December 2021  2021
# 2  8678626  804      UKR50018            50018  03 December 2021  2021
# 3  8678632  804      UKR50044            50044  03 December 2021  2021
# 4  8678655  643       RUS7261             7261  03 December 2021  2021
#
#   time_precision event_type         sub_event_type  \
# 0              1    Battles            Armed clash
# 1              1    Battles            Armed clash
# 2              1    Battles            Armed clash
# 3              1      Riots  Violent demonstration
# 4              1   Protests       Peaceful protest
#
#                                     actor1  \
# 0       Military Forces of Ukraine (2019-)
# 1  NAF: United Armed Forces of Novorossiya
# 2  NAF: United Armed Forces of Novorossiya
# 3                        Rioters (Ukraine)
# ...

# %%
data.describe()
# Out:
#         data_id    iso event_id_cnty event_id_no_cnty       event_date   year  \
# count     48635  48635         48635            48635            48635  48635
# unique    48635      5         48635            43111             1096      4
# top     8678620    804      UKR49956             2573  23 January 2021   2019
# freq          1  35852             1                3              228  18856
#
#        time_precision                  event_type  \
# count           48635                       48635
# unique              3                           6
# top                 1  Explosions/Remote violence
# freq            48274                       16594
#
#                            sub_event_type  \
# count                               48635
# unique                                 21
# top     Shelling/artillery/missile attack
# freq                                16286
#
#                                          actor1 assoc_actor_1 inter1 actor2  \
# ...

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
## save out only certain columns

# %%
data.drop(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'time_precision', 'event_type', 'assoc_actor_1', 'assoc_actor_2', 'inter1', 'inter2', 'interaction', 'region', 'country', 'admin2', 'admin3', 'geo_precision', 'source_scale', 'timestamp', 'iso3'], axis=1, inplace=True )

# %%
data.head()
# Out:
#          event_date  year         sub_event_type  \
# 0  03 December 2021  2021            Armed clash
# 1  03 December 2021  2021            Armed clash
# 2  03 December 2021  2021            Armed clash
# 3  03 December 2021  2021  Violent demonstration
# 4  03 December 2021  2021       Peaceful protest
#
#                                     actor1  \
# 0       Military Forces of Ukraine (2019-)
# 1  NAF: United Armed Forces of Novorossiya
# 2  NAF: United Armed Forces of Novorossiya
# 3                        Rioters (Ukraine)
# 4                      Protesters (Russia)
#
#                                     actor2      admin1            location  \
# 0  NAF: United Armed Forces of Novorossiya     Donetsk    Staromykhaylivka
# 1       Military Forces of Ukraine (2019-)     Luhansk             Popasna
# 2       Military Forces of Ukraine (2019-)     Luhansk  Stanytsia Luhanska
# 3         Police Forces of Ukraine (2019-)       Odesa         Chornomorsk
# ...

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 48635 entries, 0 to 48634
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   event_date      48635 non-null  object
#  1   year            48635 non-null  object
#  2   sub_event_type  48635 non-null  object
#  3   actor1          48635 non-null  object
#  4   actor2          48635 non-null  object
#  5   admin1          48635 non-null  object
#  6   location        48635 non-null  object
#  7   latitude        48635 non-null  object
#  8   longitude       48635 non-null  object
#  9   source          48635 non-null  object
#  10  notes           48635 non-null  object
#  11  fatalities      48635 non-null  object
#  12  geometry        0 non-null      geometry
# dtypes: geometry(1), object(12)
# memory usage: 4.8+ MB

# %%
data.sub_event_type.describe()
# Out:
# count                                 48635
# unique                                   21
# top       Shelling/artillery/missile attack
# freq                                  16286
# Name: sub_event_type, dtype: object

# %%
data.sub_event_type.value_counts(normalize=True)
# Out:
# Shelling/artillery/missile attack     0.334862
# Peaceful protest                      0.304945
# Armed clash                           0.295672
# Protest with intervention             0.025311
# Attack                                0.008636
# Remote explosive/landmine/IED         0.004421
# Violent demonstration                 0.004236
# Disrupted weapons use                 0.004051
# Mob violence                          0.003927
# Looting/property destruction          0.003845
# Change to group/activity              0.002673
# Arrests                               0.002241
# Other                                 0.001275
# Air/drone strike                      0.001008
# Excessive force against protesters    0.001008
# Grenade                               0.000822
# Sexual violence                       0.000514
# Agreement                             0.000247
# Abduction/forced disappearance        0.000206
# Suicide bomb                          0.000082
# ...

# %%
data.to_file('cleaned_conflicts.csv', driver='CSV')
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# fiona\ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona\_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: Attempt to create csv layer (file) against a non-directory datasource.
#
# During handling of the above exception, another exception occurred:
#
# DriverIOError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19620/1588093551.py in <module>
# ----> 1 data.to_file('cleaned_conflicts.csv', driver='CSV')
#
# ~\anaconda3\envs\ukraineConflicts\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1112         from geopandas.io.file import _to_file
#    1113
# -> 1114         _to_file(self, filename, driver, schema, index, **kwargs)
#    1115
# ...
